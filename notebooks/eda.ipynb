# %% [markdown]
# # Exploratory Data Analysis
#
# This notebook supports the Churn & Retention Intelligence Platform.

# %%
import pandas as pd
df = pd.read_csv('../data/churn_retention_data.csv')
df.head()
